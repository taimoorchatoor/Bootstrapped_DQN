# %%
import numpy as np
import gym
import tensorflow as tf
from tensorflow.contrib.layers import flatten, conv2d, fully_connected
from collections import deque, Counter
import random
from datetime import datetime
import matplotlib.pyplot as plt
import math

# %%
model_name = "Bootstrap"

# %%
gym.envs.register(
    id='CartPole-v3',
    entry_point='gym.envs.classic_control:CartPoleEnv',
    max_episode_steps=2000,
    reward_threshold=-110.0,
)

# %%
env = gym.make('CartPole-v3')
n_outputs = env.action_space.n
# Out:
# [2019-01-01 15:22:57,197] Making new env: CartPole-v3

# %%
tf.reset_default_graph()
def q_network(X, name_scope, model_name):
    # Initialize layers
    if model_name == "Bootstrap":
        output = []
        
        initializer = tf.contrib.layers.variance_scaling_initializer()
        
        with tf.variable_scope(name_scope) as scope:
            fc1 = fully_connected(X, num_outputs = 24, activation_fn=tf.nn.relu, weights_initializer=initializer)
        
            for i in range(10):
                with tf.variable_scope("heads_" + str(i)):

                    fc2 = fully_connected(fc1, num_outputs = 24, activation_fn=tf.nn.relu, weights_initializer=initializer)

                    temp_output = fully_connected(fc2, num_outputs=n_outputs, activation_fn=None, weights_initializer=initializer)

                    output.append(temp_output)

            # Vars will store the parameters of the network such as weights
        varibles = {v.name[len(scope.name):]: v for v in tf.get_collection(key = tf.GraphKeys.TRAINABLE_VARIABLES, scope = scope.name)}
        return varibles, output
        
    if model_name == "DQN":
            
        # Initialize layers
        initializer = tf.contrib.layers.variance_scaling_initializer()

        with tf.variable_scope(name_scope) as scope: 

            fc1 = fully_connected(X, num_outputs = 24, activation_fn=tf.nn.relu, weights_initializer=initializer)
            tf.summary.histogram('fc1',fc1)
            
            fc2 = fully_connected(fc1, num_outputs = 24, activation_fn=tf.nn.relu, weights_initializer=initializer)
            tf.summary.histogram('fc2',fc2)

            output = fully_connected(fc2, num_outputs=n_outputs, activation_fn=None, weights_initializer=initializer)
            tf.summary.histogram('output',output)


            # Vars will store the parameters of the network such as weights
            varibles = {v.name[len(scope.name):]: v for v in tf.get_collection(key=tf.GraphKeys.TRAINABLE_VARIABLES, scope=scope.name)} 
            return varibles, output

# %%
eps_min = 0.05
eps_max = 1.0
eps_decay = 200
steps_done = 0

def epsilon_greedy(action):
    global steps_done
    eps_threshold = eps_min+(eps_max-eps_min)*math.exp(-1.*steps_done/eps_decay)
    steps_done += 1
    if np.random.rand() < eps_threshold:
        return np.random.randint(n_outputs)
    else:
        if type(action) == np.ndarray and len(action) == 1:
            return action[0]
        return action

# %%
buffer_len = 10000
exp_buffer = deque(maxlen=buffer_len)

# %%
def sample_memories(batch_size):
    perm_batch = np.random.permutation(len(exp_buffer))[:batch_size]
    mem = np.array(exp_buffer)[perm_batch]
    return mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]

# %%
num_episodes = 20
batch_size = 128
input_shape = (None, 4,)
learning_rate = 0.001
X_shape = (None, 4,)
discount_factor = 0.999

global_step = 0
copy_steps = 100
steps_train = 4
start_steps = 2000

# %%
logdir = 'logs'
tf.reset_default_graph()

# Now we define the placeholder for our input i.e game state
X = tf.placeholder(tf.float32, shape=X_shape)

# we define a boolean called in_training_model to toggle the training
in_training_mode = tf.placeholder(tf.bool)

# %%
# we build our Q network, which takes the input X and generates Q values for all the actions in the state
mainQ, mainQ_outputs = q_network(X, 'mainQ',model_name)

# similarly we build our target Q network
targetQ, targetQ_outputs = q_network(X, 'targetQ',model_name)

# %%
# define the placeholder for our action values
X_action = tf.placeholder(tf.int32, shape=(None,))
Q_action = tf.reduce_sum(targetQ_outputs * tf.one_hot(X_action, n_outputs), axis=-1, keep_dims=True)
# Out:
# [2019-01-01 15:22:58,794] From <ipython-input-12-2e17235474d5>:3: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
copy_op = [tf.assign(main_name, targetQ[var_name]) for var_name, main_name in mainQ.items()]
copy_target_to_main = tf.group(*copy_op)

# %%
# define a placeholder for our output i.e action
y = tf.placeholder(tf.float32, shape=(None,1))

# now we calculate the loss which is the difference between actual value and predicted value
loss = tf.reduce_mean(tf.square(y - Q_action))

# we use adam optimizer for minimizing the loss
optimizer = tf.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()

loss_summary = tf.summary.scalar('LOSS', loss)
merge_summary = tf.summary.merge_all()
file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())

# %%
import pandas as pd
number_of_epochs = []
rewards_of_episode = []
with tf.Session() as sess:
    init.run()
    # for each episode
    for i in range(50000):
        done = False
        obs = env.reset()
        epoch = 0
        episodic_reward = 0
        actions_counter = Counter() 
        episodic_loss = []

        # while the state is not the terminal state
        while not done:

            #env.render()
            if model_name == "Bootstrap":
                head = int(np.random.uniform() * 10)

            # feed the game screen and get the Q values for each action
            if model_name == "Bootstrap":
                actions = mainQ_outputs[head].eval(feed_dict={X:[obs], in_training_mode:False})
            elif model_name == "DQN":
                actions = mainQ_outputs.eval(feed_dict={X:[obs], in_training_mode:False})
            
            # get the action
            action = np.argmax(actions, axis=-1)
            actions_counter[str(action)] += 1 
            
            # select the action using epsilon greedy policy
            action = epsilon_greedy(action)
            
            # now perform the action and move to the next state, next_obs, receive reward
            next_obs, reward, done, _ = env.step(action)

            # Store this transistion as an experience in the replay buffer
            exp_buffer.append([obs, action, next_obs, reward, done])
            
            # After certain steps, we train our Q network with samples from the experience replay buffer
            if global_step % steps_train == 0 and global_step > batch_size:
                
                # sample experience
                o_obs, o_act, o_next_obs, o_rew, o_done = sample_memories(batch_size)

                # states
                o_obs = [x for x in o_obs]

                # next states
                o_next_obs = [x for x in o_next_obs]

                # next actions
                if model_name == "Bootstrap":
                    next_act = mainQ_outputs[head].eval(feed_dict={X:o_next_obs, in_training_mode:False})
                elif model_name == "DQN":
                    next_act = mainQ_outputs.eval(feed_dict={X:o_next_obs, in_training_mode:False})

                # reward
                y_batch = o_rew + discount_factor * np.max(next_act, axis = -1) * (1 - o_done) 

                # merge all summaries and write to the file
                mrg_summary = merge_summary.eval(feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:False})
                file_writer.add_summary(mrg_summary, global_step)

                # now we train the network and calculate loss
                train_loss, _ = sess.run([loss, training_op], feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:True})
                episodic_loss.append(train_loss)
            
            # after some interval we copy our main Q network weights to target Q network
            if (global_step + 1) % copy_steps == 0 and global_step > batch_size:
                copy_target_to_main.run()
                
            obs = next_obs
            epoch += 1
            global_step += 1
            episodic_reward += reward
            if i%100==0:
                result = pd.DataFrame(data = rewards_of_episode, columns = [['Rewards']])
                writer = pd.ExcelWriter('boot_cartpole_10heads_3.xlsx')
                result.to_excel(writer,'Sheet1')
                writer.save()
        rewards_of_episode.append(episodic_reward)
        number_of_epochs.append(epoch)
        print('Epoch', epoch, 'Reward', episodic_reward,'Steps',steps_done)
# Out:
# Epoch 22 Reward 22.0 Steps 22
# Epoch 30 Reward 30.0 Steps 52
# Epoch 36 Reward 36.0 Steps 88
# Epoch 19 Reward 19.0 Steps 107
# Epoch 14 Reward 14.0 Steps 121
# Epoch 27 Reward 27.0 Steps 148
# Epoch 26 Reward 26.0 Steps 174
# Epoch 40 Reward 40.0 Steps 214
# Epoch 14 Reward 14.0 Steps 228
# Epoch 11 Reward 11.0 Steps 239
# Epoch 21 Reward 21.0 Steps 260
# Epoch 15 Reward 15.0 Steps 275
# Epoch 10 Reward 10.0 Steps 285
# Epoch 17 Reward 17.0 Steps 302
# Epoch 15 Reward 15.0 Steps 317
# Epoch 8 Reward 8.0 Steps 325
# Epoch 13 Reward 13.0 Steps 338
# Epoch 11 Reward 11.0 Steps 349
# Epoch 13 Reward 13.0 Steps 362
# Epoch 21 Reward 21.0 Steps 383
# Epoch 11 Reward 11.0 Steps 394
# Epoch 16 Reward 16.0 Steps 410
# Epoch 10 Reward 10.0 Steps 420
# Epoch 10 Reward 10.0 Steps 430
# Epoch 10 Reward 10.0 Steps 440
# Epoch 16 Reward 16.0 Steps 456
# Epoch 9 Reward 9.0 Steps 465
# Epoch 10 Reward 10.0 Steps 475
# Epoch 10 Reward 10.0 Steps 485
# Epoch 9 Reward 9.0 Steps 494
# Epoch 8 Reward 8.0 Steps 502
# Epoch 11 Reward 11.0 Steps 513
# Epoch 10 Reward 10.0 Steps 523
# Epoch 8 Reward 8.0 Steps 531
# Epoch 10 Reward 10.0 Steps 541
# Epoch 11 Reward 11.0 Steps 552
# Epoch 9 Reward 9.0 Steps 561
# Epoch 8 Reward 8.0 Steps 569
# Epoch 11 Reward 11.0 Steps 580
# Epoch 10 Reward 10.0 Steps 590
# Epoch 9 Reward 9.0 Steps 599
# Epoch 10 Reward 10.0 Steps 609
# Epoch 10 Reward 10.0 Steps 619
# Epoch 9 Reward 9.0 Steps 628
# Epoch 10 Reward 10.0 Steps 638
# Epoch 11 Reward 11.0 Steps 649
# Epoch 10 Reward 10.0 Steps 659
# Epoch 10 Reward 10.0 Steps 669
# Epoch 13 Reward 13.0 Steps 682
# Epoch 9 Reward 9.0 Steps 691
# Epoch 9 Reward 9.0 Steps 700
# Epoch 9 Reward 9.0 Steps 709
# Epoch 10 Reward 10.0 Steps 719
# Epoch 10 Reward 10.0 Steps 729
# Epoch 8 Reward 8.0 Steps 737
# Epoch 12 Reward 12.0 Steps 749
# Epoch 10 Reward 10.0 Steps 759
# Epoch 10 Reward 10.0 Steps 769
# Epoch 10 Reward 10.0 Steps 779
# Epoch 10 Reward 10.0 Steps 789
# Epoch 12 Reward 12.0 Steps 801
# Epoch 10 Reward 10.0 Steps 811
# Epoch 9 Reward 9.0 Steps 820
# Epoch 10 Reward 10.0 Steps 830
# Epoch 10 Reward 10.0 Steps 840
# Epoch 9 Reward 9.0 Steps 849
# Epoch 9 Reward 9.0 Steps 858
# Epoch 10 Reward 10.0 Steps 868
# Epoch 17 Reward 17.0 Steps 885
# Epoch 9 Reward 9.0 Steps 894
# Epoch 10 Reward 10.0 Steps 904
# Epoch 10 Reward 10.0 Steps 914
# Epoch 10 Reward 10.0 Steps 924
# Epoch 10 Reward 10.0 Steps 934
# Epoch 11 Reward 11.0 Steps 945
# Epoch 9 Reward 9.0 Steps 954
# Epoch 9 Reward 9.0 Steps 963
# Epoch 10 Reward 10.0 Steps 973
# Epoch 9 Reward 9.0 Steps 982
# Epoch 10 Reward 10.0 Steps 992
# Epoch 10 Reward 10.0 Steps 1002
# Epoch 9 Reward 9.0 Steps 1011
# Epoch 8 Reward 8.0 Steps 1019
# Epoch 8 Reward 8.0 Steps 1027
# Epoch 9 Reward 9.0 Steps 1036
# Epoch 9 Reward 9.0 Steps 1045
# Epoch 9 Reward 9.0 Steps 1054
# Epoch 15 Reward 15.0 Steps 1069
# Epoch 12 Reward 12.0 Steps 1081
# Epoch 9 Reward 9.0 Steps 1090
# Epoch 9 Reward 9.0 Steps 1099
# Epoch 9 Reward 9.0 Steps 1108
# Epoch 9 Reward 9.0 Steps 1117
# Epoch 8 Reward 8.0 Steps 1125
# Epoch 10 Reward 10.0 Steps 1135
# Epoch 10 Reward 10.0 Steps 1145
# Epoch 12 Reward 12.0 Steps 1157
# Epoch 10 Reward 10.0 Steps 1167
# Epoch 10 Reward 10.0 Steps 1177
# Epoch 9 Reward 9.0 Steps 1186
# Epoch 9 Reward 9.0 Steps 1195
# Epoch 16 Reward 16.0 Steps 1211
# Epoch 12 Reward 12.0 Steps 1223
# Epoch 9 Reward 9.0 Steps 1232
# Epoch 12 Reward 12.0 Steps 1244
# Epoch 8 Reward 8.0 Steps 1252
# Epoch 11 Reward 11.0 Steps 1263
# Epoch 9 Reward 9.0 Steps 1272
# Epoch 11 Reward 11.0 Steps 1283
# Epoch 11 Reward 11.0 Steps 1294
# Epoch 10 Reward 10.0 Steps 1304
# Epoch 12 Reward 12.0 Steps 1316
# Epoch 11 Reward 11.0 Steps 1327
# Epoch 10 Reward 10.0 Steps 1337
# Epoch 11 Reward 11.0 Steps 1348
# Epoch 11 Reward 11.0 Steps 1359
# Epoch 14 Reward 14.0 Steps 1373
# Epoch 9 Reward 9.0 Steps 1382
# Epoch 10 Reward 10.0 Steps 1392
# Epoch 9 Reward 9.0 Steps 1401
# Epoch 16 Reward 16.0 Steps 1417
# Epoch 10 Reward 10.0 Steps 1427
# Epoch 11 Reward 11.0 Steps 1438
# Epoch 11 Reward 11.0 Steps 1449
# Epoch 11 Reward 11.0 Steps 1460
# Epoch 10 Reward 10.0 Steps 1470
# Epoch 8 Reward 8.0 Steps 1478
# Epoch 10 Reward 10.0 Steps 1488
# Epoch 8 Reward 8.0 Steps 1496
# Epoch 11 Reward 11.0 Steps 1507
# Epoch 10 Reward 10.0 Steps 1517
# Epoch 9 Reward 9.0 Steps 1526
# Epoch 12 Reward 12.0 Steps 1538
# Epoch 10 Reward 10.0 Steps 1548
# Epoch 11 Reward 11.0 Steps 1559
# Epoch 12 Reward 12.0 Steps 1571
# Epoch 9 Reward 9.0 Steps 1580
# Epoch 10 Reward 10.0 Steps 1590
# Epoch 9 Reward 9.0 Steps 1599
# Epoch 11 Reward 11.0 Steps 1610
# Epoch 12 Reward 12.0 Steps 1622
# Epoch 15 Reward 15.0 Steps 1637
# Epoch 9 Reward 9.0 Steps 1646
# Epoch 12 Reward 12.0 Steps 1658
# Epoch 9 Reward 9.0 Steps 1667
# Epoch 11 Reward 11.0 Steps 1678
# Epoch 11 Reward 11.0 Steps 1689
# Epoch 10 Reward 10.0 Steps 1699
# Epoch 26 Reward 26.0 Steps 1725
# Epoch 9 Reward 9.0 Steps 1734
# Epoch 10 Reward 10.0 Steps 1744
# Epoch 11 Reward 11.0 Steps 1755
# Epoch 9 Reward 9.0 Steps 1764
# Epoch 12 Reward 12.0 Steps 1776
# Epoch 20 Reward 20.0 Steps 1796
# Epoch 25 Reward 25.0 Steps 1821
# Epoch 15 Reward 15.0 Steps 1836
# Epoch 12 Reward 12.0 Steps 1848
# Epoch 13 Reward 13.0 Steps 1861
# Epoch 11 Reward 11.0 Steps 1872
# Epoch 15 Reward 15.0 Steps 1887
# Epoch 32 Reward 32.0 Steps 1919
# Epoch 33 Reward 33.0 Steps 1952
# Epoch 97 Reward 97.0 Steps 2049
# Epoch 28 Reward 28.0 Steps 2077
# Epoch 22 Reward 22.0 Steps 2099
# Epoch 17 Reward 17.0 Steps 2116
# Epoch 21 Reward 21.0 Steps 2137
# Epoch 28 Reward 28.0 Steps 2165
# Epoch 24 Reward 24.0 Steps 2189
# Epoch 20 Reward 20.0 Steps 2209
# Epoch 25 Reward 25.0 Steps 2234
# Epoch 28 Reward 28.0 Steps 2262
# Epoch 39 Reward 39.0 Steps 2301
# Epoch 84 Reward 84.0 Steps 2385
# Epoch 24 Reward 24.0 Steps 2409
# Epoch 25 Reward 25.0 Steps 2434
# Epoch 21 Reward 21.0 Steps 2455
# Epoch 26 Reward 26.0 Steps 2481
# Epoch 22 Reward 22.0 Steps 2503
# Epoch 31 Reward 31.0 Steps 2534
# Epoch 26 Reward 26.0 Steps 2560
# Epoch 25 Reward 25.0 Steps 2585
# Epoch 22 Reward 22.0 Steps 2607
# Epoch 16 Reward 16.0 Steps 2623
# Epoch 20 Reward 20.0 Steps 2643
# Epoch 18 Reward 18.0 Steps 2661
# Epoch 18 Reward 18.0 Steps 2679
# Epoch 12 Reward 12.0 Steps 2691
# Epoch 15 Reward 15.0 Steps 2706
# Epoch 39 Reward 39.0 Steps 2745
# Epoch 35 Reward 35.0 Steps 2780
# Epoch 39 Reward 39.0 Steps 2819
# Epoch 33 Reward 33.0 Steps 2852
# Epoch 26 Reward 26.0 Steps 2878
# Epoch 29 Reward 29.0 Steps 2907
# Epoch 17 Reward 17.0 Steps 2924
# Epoch 24 Reward 24.0 Steps 2948
# Epoch 24 Reward 24.0 Steps 2972
# Epoch 22 Reward 22.0 Steps 2994
# Epoch 40 Reward 40.0 Steps 3034
# Epoch 37 Reward 37.0 Steps 3071
# Epoch 41 Reward 41.0 Steps 3112
# Epoch 29 Reward 29.0 Steps 3141
# Epoch 28 Reward 28.0 Steps 3169
# Epoch 32 Reward 32.0 Steps 3201
# Epoch 48 Reward 48.0 Steps 3249
# Epoch 47 Reward 47.0 Steps 3296
# Epoch 80 Reward 80.0 Steps 3376
# Epoch 54 Reward 54.0 Steps 3430
# Epoch 51 Reward 51.0 Steps 3481
# Epoch 67 Reward 67.0 Steps 3548
# Epoch 29 Reward 29.0 Steps 3577
# Epoch 28 Reward 28.0 Steps 3605
# Epoch 78 Reward 78.0 Steps 3683
# Epoch 55 Reward 55.0 Steps 3738
# Epoch 36 Reward 36.0 Steps 3774
# Epoch 71 Reward 71.0 Steps 3845
# Epoch 80 Reward 80.0 Steps 3925
# Epoch 33 Reward 33.0 Steps 3958
# Epoch 34 Reward 34.0 Steps 3992
# Epoch 37 Reward 37.0 Steps 4029
# Epoch 48 Reward 48.0 Steps 4077
# Epoch 30 Reward 30.0 Steps 4107
# Epoch 39 Reward 39.0 Steps 4146
# Epoch 46 Reward 46.0 Steps 4192
# Epoch 76 Reward 76.0 Steps 4268
# Epoch 49 Reward 49.0 Steps 4317
# Epoch 51 Reward 51.0 Steps 4368
# Epoch 79 Reward 79.0 Steps 4447
# Epoch 44 Reward 44.0 Steps 4491
# Epoch 68 Reward 68.0 Steps 4559
# Epoch 95 Reward 95.0 Steps 4654
# Epoch 48 Reward 48.0 Steps 4702
# Epoch 50 Reward 50.0 Steps 4752
# Epoch 60 Reward 60.0 Steps 4812
# Epoch 81 Reward 81.0 Steps 4893
# Epoch 91 Reward 91.0 Steps 4984
# Epoch 74 Reward 74.0 Steps 5058
# Epoch 61 Reward 61.0 Steps 5119
# Epoch 66 Reward 66.0 Steps 5185
# Epoch 48 Reward 48.0 Steps 5233
# Epoch 38 Reward 38.0 Steps 5271
# Epoch 102 Reward 102.0 Steps 5373
# Epoch 70 Reward 70.0 Steps 5443
# Epoch 117 Reward 117.0 Steps 5560
# Epoch 136 Reward 136.0 Steps 5696
# Epoch 93 Reward 93.0 Steps 5789
# Epoch 122 Reward 122.0 Steps 5911
# Epoch 88 Reward 88.0 Steps 5999
# Epoch 134 Reward 134.0 Steps 6133
# Epoch 121 Reward 121.0 Steps 6254
# Epoch 208 Reward 208.0 Steps 6462
# Epoch 170 Reward 170.0 Steps 6632
# Epoch 136 Reward 136.0 Steps 6768
# Epoch 255 Reward 255.0 Steps 20888
# Epoch 466 Reward 466.0 Steps 21354
# Epoch 205 Reward 205.0 Steps 21559
# Epoch 197 Reward 197.0 Steps 21756
# Epoch 313 Reward 313.0 Steps 22069
# Epoch 392 Reward 392.0 Steps 22461
# Epoch 228 Reward 228.0 Steps 22689
# Epoch 256 Reward 256.0 Steps 22945
# Epoch 258 Reward 258.0 Steps 23203
# Epoch 151 Reward 151.0 Steps 23354
# Epoch 233 Reward 233.0 Steps 23587
# Epoch 268 Reward 268.0 Steps 23855
# Epoch 252 Reward 252.0 Steps 24107
# Epoch 236 Reward 236.0 Steps 24343
# Epoch 336 Reward 336.0 Steps 24679
# Epoch 250 Reward 250.0 Steps 24929
# Epoch 240 Reward 240.0 Steps 25169
# Epoch 227 Reward 227.0 Steps 25396
# Epoch 298 Reward 298.0 Steps 25694
# Epoch 177 Reward 177.0 Steps 25871
# Epoch 408 Reward 408.0 Steps 26279
# Epoch 350 Reward 350.0 Steps 26629
# Epoch 248 Reward 248.0 Steps 26877
# Epoch 295 Reward 295.0 Steps 27172
# Epoch 145 Reward 145.0 Steps 27317
# Epoch 317 Reward 317.0 Steps 27634
# Epoch 209 Reward 209.0 Steps 27843
# Epoch 395 Reward 395.0 Steps 28238
# Epoch 324 Reward 324.0 Steps 28562
# Epoch 182 Reward 182.0 Steps 28744
# Epoch 1700 Reward 1700.0 Steps 30444
# Epoch 2000 Reward 2000.0 Steps 32444
# Epoch 1859 Reward 1859.0 Steps 34303
# Epoch 419 Reward 419.0 Steps 34722
# Epoch 275 Reward 275.0 Steps 34997
# Epoch 350 Reward 350.0 Steps 35347
# Epoch 433 Reward 433.0 Steps 35780
# Epoch 466 Reward 466.0 Steps 36246
# Epoch 652 Reward 652.0 Steps 36898
# Epoch 593 Reward 593.0 Steps 37491
# Epoch 2000 Reward 2000.0 Steps 39491
# Epoch 738 Reward 738.0 Steps 40229
# Epoch 536 Reward 536.0 Steps 40765
# Epoch 564 Reward 564.0 Steps 41329
# Epoch 1103 Reward 1103.0 Steps 42432
# Epoch 563 Reward 563.0 Steps 42995
# Epoch 171 Reward 171.0 Steps 43166
# Epoch 827 Reward 827.0 Steps 43993
# Epoch 529 Reward 529.0 Steps 44522
# Epoch 593 Reward 593.0 Steps 45115
# Epoch 2000 Reward 2000.0 Steps 47115
# Epoch 2000 Reward 2000.0 Steps 49115
# Epoch 2000 Reward 2000.0 Steps 51115
# Epoch 2000 Reward 2000.0 Steps 53115
# Epoch 2000 Reward 2000.0 Steps 55115
# Epoch 2000 Reward 2000.0 Steps 57115
# Epoch 2000 Reward 2000.0 Steps 59115
# Epoch 2000 Reward 2000.0 Steps 61115
# Epoch 2000 Reward 2000.0 Steps 63115
# Epoch 2000 Reward 2000.0 Steps 65115
# Epoch 2000 Reward 2000.0 Steps 67115
# Epoch 2000 Reward 2000.0 Steps 69115
# Epoch 2000 Reward 2000.0 Steps 71115
# Epoch 2000 Reward 2000.0 Steps 73115
# Epoch 2000 Reward 2000.0 Steps 75115
# Epoch 527 Reward 527.0 Steps 202638
# Epoch 571 Reward 571.0 Steps 203209
# Epoch 551 Reward 551.0 Steps 203760
# Epoch 622 Reward 622.0 Steps 204382
# Epoch 586 Reward 586.0 Steps 204968
# Epoch 682 Reward 682.0 Steps 205650
# Epoch 691 Reward 691.0 Steps 206341
# Epoch 649 Reward 649.0 Steps 206990
# Epoch 640 Reward 640.0 Steps 207630
# Epoch 764 Reward 764.0 Steps 208394
# Epoch 875 Reward 875.0 Steps 209269
# Epoch 910 Reward 910.0 Steps 210179
# Epoch 1185 Reward 1185.0 Steps 211364
# Epoch 1874 Reward 1874.0 Steps 213238
# Epoch 2000 Reward 2000.0 Steps 215238
# Epoch 2000 Reward 2000.0 Steps 217238
# Epoch 2000 Reward 2000.0 Steps 219238
# Epoch 2000 Reward 2000.0 Steps 221238
# Epoch 2000 Reward 2000.0 Steps 223238
# Epoch 2000 Reward 2000.0 Steps 225238
# Epoch 2000 Reward 2000.0 Steps 227238
# Epoch 2000 Reward 2000.0 Steps 229238
# Epoch 2000 Reward 2000.0 Steps 231238
# Epoch 1276 Reward 1276.0 Steps 232514
# Epoch 303 Reward 303.0 Steps 232817
# Epoch 345 Reward 345.0 Steps 233162
# Epoch 2000 Reward 2000.0 Steps 235162
# Epoch 2000 Reward 2000.0 Steps 237162
# Epoch 2000 Reward 2000.0 Steps 239162
# Epoch 2000 Reward 2000.0 Steps 241162
# Epoch 2000 Reward 2000.0 Steps 243162
# Epoch 2000 Reward 2000.0 Steps 245162
# Epoch 2000 Reward 2000.0 Steps 247162
# Epoch 1446 Reward 1446.0 Steps 248608
# Epoch 14 Reward 14.0 Steps 248622
# Epoch 434 Reward 434.0 Steps 249056
# Epoch 381 Reward 381.0 Steps 249437
# Epoch 315 Reward 315.0 Steps 249752
# Epoch 194 Reward 194.0 Steps 249946
# Epoch 11 Reward 11.0 Steps 249957
# Epoch 199 Reward 199.0 Steps 250156
# Epoch 191 Reward 191.0 Steps 250347
# Epoch 10 Reward 10.0 Steps 250357
# Epoch 12 Reward 12.0 Steps 250369
# Epoch 14 Reward 14.0 Steps 250383
# Epoch 12 Reward 12.0 Steps 250395
# Epoch 10 Reward 10.0 Steps 250405
# Epoch 9 Reward 9.0 Steps 250414
# Epoch 10 Reward 10.0 Steps 250424
# Epoch 11 Reward 11.0 Steps 250435
# Epoch 10 Reward 10.0 Steps 250445
# Epoch 12 Reward 12.0 Steps 250457
# Epoch 9 Reward 9.0 Steps 250466
# Epoch 10 Reward 10.0 Steps 250476
# Epoch 10 Reward 10.0 Steps 250486
# Epoch 10 Reward 10.0 Steps 250496
# Epoch 11 Reward 11.0 Steps 250507
# Epoch 12 Reward 12.0 Steps 250519
# Epoch 10 Reward 10.0 Steps 250529
# Epoch 10 Reward 10.0 Steps 250539
# Epoch 10 Reward 10.0 Steps 250549
# Epoch 9 Reward 9.0 Steps 250558
# Epoch 9 Reward 9.0 Steps 250567
# Epoch 9 Reward 9.0 Steps 250576
# Epoch 10 Reward 10.0 Steps 250586
# Epoch 2000 Reward 2000.0 Steps 465049
# Epoch 2000 Reward 2000.0 Steps 467049
# Epoch 2000 Reward 2000.0 Steps 469049
# Epoch 2000 Reward 2000.0 Steps 471049
# Epoch 2000 Reward 2000.0 Steps 473049
# Epoch 2000 Reward 2000.0 Steps 475049
# Epoch 2000 Reward 2000.0 Steps 477049
# Epoch 2000 Reward 2000.0 Steps 479049
# Epoch 2000 Reward 2000.0 Steps 481049
# Epoch 2000 Reward 2000.0 Steps 483049
# Epoch 2000 Reward 2000.0 Steps 485049
# Epoch 2000 Reward 2000.0 Steps 487049
# Epoch 2000 Reward 2000.0 Steps 489049
# Epoch 2000 Reward 2000.0 Steps 491049
# Epoch 2000 Reward 2000.0 Steps 493049
# Epoch 2000 Reward 2000.0 Steps 495049
# Epoch 2000 Reward 2000.0 Steps 497049
# Epoch 2000 Reward 2000.0 Steps 499049
# Epoch 2000 Reward 2000.0 Steps 501049
# Epoch 2000 Reward 2000.0 Steps 503049
# Epoch 2000 Reward 2000.0 Steps 505049
# Epoch 2000 Reward 2000.0 Steps 507049
# Epoch 2000 Reward 2000.0 Steps 509049
# Epoch 2000 Reward 2000.0 Steps 511049
# Epoch 1416 Reward 1416.0 Steps 512465
# Epoch 151 Reward 151.0 Steps 512616
# Epoch 12 Reward 12.0 Steps 512628
# Epoch 11 Reward 11.0 Steps 512639
# Epoch 11 Reward 11.0 Steps 512650
# Epoch 13 Reward 13.0 Steps 512663
# Epoch 13 Reward 13.0 Steps 512676
# Epoch 10 Reward 10.0 Steps 512686
# Epoch 11 Reward 11.0 Steps 512697
# Epoch 114 Reward 114.0 Steps 512811
# Epoch 100 Reward 100.0 Steps 512911
# Epoch 234 Reward 234.0 Steps 513145
# Epoch 17 Reward 17.0 Steps 513162
# Epoch 13 Reward 13.0 Steps 513175
# Epoch 19 Reward 19.0 Steps 513194
# Epoch 10 Reward 10.0 Steps 513204
# Epoch 10 Reward 10.0 Steps 513214
# Epoch 13 Reward 13.0 Steps 513227
# Epoch 13 Reward 13.0 Steps 513240
# Epoch 10 Reward 10.0 Steps 513250
# Epoch 17 Reward 17.0 Steps 513267
# Epoch 11 Reward 11.0 Steps 513278
# Epoch 21 Reward 21.0 Steps 513299
# Epoch 18 Reward 18.0 Steps 513317
# Epoch 11 Reward 11.0 Steps 513328
# Epoch 16 Reward 16.0 Steps 513344
# Epoch 12 Reward 12.0 Steps 513356
# Epoch 309 Reward 309.0 Steps 513665
# Epoch 1567 Reward 1567.0 Steps 515232
# Epoch 168 Reward 168.0 Steps 515400
# Epoch 173 Reward 173.0 Steps 515573
# Epoch 201 Reward 201.0 Steps 515774
# Epoch 183 Reward 183.0 Steps 515957
# Epoch 181 Reward 181.0 Steps 516138
# Epoch 188 Reward 188.0 Steps 516326
# Epoch 553 Reward 553.0 Steps 516879
# Epoch 758 Reward 758.0 Steps 517637
# Epoch 346 Reward 346.0 Steps 517983
# Epoch 317 Reward 317.0 Steps 518300
# Epoch 297 Reward 297.0 Steps 518597
# Epoch 242 Reward 242.0 Steps 518839
# Epoch 271 Reward 271.0 Steps 519110
# Epoch 250 Reward 250.0 Steps 519360
# Epoch 581 Reward 581.0 Steps 519941
# Epoch 393 Reward 393.0 Steps 520334
# Epoch 241 Reward 241.0 Steps 520575
# Epoch 355 Reward 355.0 Steps 520930
# Epoch 378 Reward 378.0 Steps 521308
# Epoch 565 Reward 565.0 Steps 521873
# Epoch 278 Reward 278.0 Steps 522151
# Epoch 252 Reward 252.0 Steps 522403
# Epoch 267 Reward 267.0 Steps 522670
# Epoch 348 Reward 348.0 Steps 523018
# Epoch 252 Reward 252.0 Steps 523270
# Epoch 202 Reward 202.0 Steps 523472
# Epoch 204 Reward 204.0 Steps 523676
# Epoch 230 Reward 230.0 Steps 523906
# Epoch 209 Reward 209.0 Steps 524115
# Epoch 224 Reward 224.0 Steps 524339
# Epoch 208 Reward 208.0 Steps 524547
# Epoch 211 Reward 211.0 Steps 524758
# Epoch 215 Reward 215.0 Steps 524973
# Epoch 220 Reward 220.0 Steps 525193
# Epoch 196 Reward 196.0 Steps 525389
# Epoch 194 Reward 194.0 Steps 525583
# Epoch 202 Reward 202.0 Steps 525785
# Epoch 220 Reward 220.0 Steps 526005
# Epoch 180 Reward 180.0 Steps 526185
# Epoch 199 Reward 199.0 Steps 526384
# Epoch 184 Reward 184.0 Steps 526568
# Epoch 225 Reward 225.0 Steps 526793
# Epoch 221 Reward 221.0 Steps 527014
# Epoch 198 Reward 198.0 Steps 527212
# Epoch 197 Reward 197.0 Steps 527409
# Epoch 217 Reward 217.0 Steps 527626
# Epoch 189 Reward 189.0 Steps 527815
# Epoch 196 Reward 196.0 Steps 528011
# Epoch 195 Reward 195.0 Steps 528206
# Epoch 209 Reward 209.0 Steps 528415
# Epoch 215 Reward 215.0 Steps 528630
# Epoch 212 Reward 212.0 Steps 528842
# Epoch 222 Reward 222.0 Steps 529064
# Epoch 206 Reward 206.0 Steps 529270
# Epoch 193 Reward 193.0 Steps 529463
# Epoch 204 Reward 204.0 Steps 529667
# Epoch 206 Reward 206.0 Steps 529873
# Epoch 190 Reward 190.0 Steps 530063
# Epoch 228 Reward 228.0 Steps 530291
# Epoch 203 Reward 203.0 Steps 530494
# Epoch 210 Reward 210.0 Steps 530704
# Epoch 212 Reward 212.0 Steps 530916
# Epoch 219 Reward 219.0 Steps 531135
# Epoch 205 Reward 205.0 Steps 531340
# Epoch 231 Reward 231.0 Steps 531571
# Epoch 220 Reward 220.0 Steps 531791
# Epoch 200 Reward 200.0 Steps 531991
# Epoch 230 Reward 230.0 Steps 532221
# Epoch 230 Reward 230.0 Steps 532451
# Epoch 208 Reward 208.0 Steps 532659
# Epoch 223 Reward 223.0 Steps 532882
# Epoch 228 Reward 228.0 Steps 533110
# Epoch 254 Reward 254.0 Steps 533364
# Epoch 249 Reward 249.0 Steps 533613
# Epoch 256 Reward 256.0 Steps 533869
# Epoch 276 Reward 276.0 Steps 534145
# Epoch 282 Reward 282.0 Steps 534427
# Epoch 2000 Reward 2000.0 Steps 640354
# Epoch 12 Reward 12.0 Steps 640366
# Epoch 992 Reward 992.0 Steps 641358
# Epoch 2000 Reward 2000.0 Steps 643358
# ...
# Epoch 276 Reward 276.0 Steps 3154335
# Epoch 258 Reward 258.0 Steps 3154593
# Epoch 258 Reward 258.0 Steps 3154851
# Epoch 373 Reward 373.0 Steps 3155224
# Epoch 340 Reward 340.0 Steps 3155564
# Epoch 281 Reward 281.0 Steps 3155845
# Epoch 398 Reward 398.0 Steps 3156243
# Epoch 389 Reward 389.0 Steps 3156632
# Epoch 311 Reward 311.0 Steps 3156943
# Epoch 309 Reward 309.0 Steps 3157252
# Epoch 293 Reward 293.0 Steps 3157545
# Epoch 310 Reward 310.0 Steps 3157855
# Epoch 369 Reward 369.0 Steps 3158224
# Epoch 508 Reward 508.0 Steps 3158732
# Epoch 328 Reward 328.0 Steps 3159060
# Epoch 266 Reward 266.0 Steps 3159326
# Epoch 253 Reward 253.0 Steps 3159579
# Epoch 336 Reward 336.0 Steps 3159915
# Epoch 369 Reward 369.0 Steps 3160284
# Epoch 330 Reward 330.0 Steps 3160614
# Epoch 440 Reward 440.0 Steps 3161054
# Epoch 567 Reward 567.0 Steps 3161621
# Epoch 657 Reward 657.0 Steps 3162278
# Epoch 596 Reward 596.0 Steps 3162874
# Epoch 830 Reward 830.0 Steps 3163704
# Epoch 1911 Reward 1911.0 Steps 3165615
# Epoch 698 Reward 698.0 Steps 3166313
# Epoch 901 Reward 901.0 Steps 3167214
# Epoch 923 Reward 923.0 Steps 3168137
# Epoch 2000 Reward 2000.0 Steps 3170137
# Epoch 979 Reward 979.0 Steps 3171116
# Epoch 328 Reward 328.0 Steps 3171444
# Epoch 440 Reward 440.0 Steps 3171884
# Epoch 733 Reward 733.0 Steps 3172617
# Epoch 223 Reward 223.0 Steps 3172840
# Epoch 175 Reward 175.0 Steps 3173015
# Epoch 206 Reward 206.0 Steps 3173221
# Epoch 259 Reward 259.0 Steps 3173480
# Epoch 254 Reward 254.0 Steps 3173734
# Epoch 180 Reward 180.0 Steps 3173914
# Epoch 172 Reward 172.0 Steps 3174086
# Epoch 147 Reward 147.0 Steps 3174233
# Epoch 163 Reward 163.0 Steps 3174396
# Epoch 168 Reward 168.0 Steps 3174564
# Epoch 166 Reward 166.0 Steps 3174730
# Epoch 155 Reward 155.0 Steps 3174885
# Epoch 165 Reward 165.0 Steps 3175050
# Epoch 168 Reward 168.0 Steps 3175218
# Epoch 142 Reward 142.0 Steps 3175360
# Epoch 191 Reward 191.0 Steps 3175551
# Epoch 180 Reward 180.0 Steps 3175731
# Epoch 227 Reward 227.0 Steps 3175958
# Epoch 190 Reward 190.0 Steps 3176148
# Epoch 213 Reward 213.0 Steps 3176361
# Epoch 264 Reward 264.0 Steps 3176625
# Epoch 289 Reward 289.0 Steps 3176914
# Epoch 280 Reward 280.0 Steps 3177194
# Epoch 338 Reward 338.0 Steps 3177532
# Epoch 273 Reward 273.0 Steps 3177805
# Epoch 214 Reward 214.0 Steps 3178019
# Epoch 197 Reward 197.0 Steps 3178216
# Epoch 191 Reward 191.0 Steps 3178407
# Epoch 213 Reward 213.0 Steps 3178620
# Epoch 201 Reward 201.0 Steps 3178821
# Epoch 216 Reward 216.0 Steps 3179037
# Epoch 212 Reward 212.0 Steps 3179249
# Epoch 239 Reward 239.0 Steps 3179488
# Epoch 250 Reward 250.0 Steps 3179738
# Epoch 219 Reward 219.0 Steps 3179957
# Epoch 234 Reward 234.0 Steps 3180191
# Epoch 311 Reward 311.0 Steps 3180502
# Epoch 353 Reward 353.0 Steps 3180855
# Epoch 2000 Reward 2000.0 Steps 3182855
# Epoch 2000 Reward 2000.0 Steps 3184855
# Epoch 2000 Reward 2000.0 Steps 3186855
# Epoch 2000 Reward 2000.0 Steps 3188855
# Epoch 2000 Reward 2000.0 Steps 3190855
# Epoch 2000 Reward 2000.0 Steps 3192855
# Epoch 2000 Reward 2000.0 Steps 3194855
# Epoch 2000 Reward 2000.0 Steps 3196855
# Epoch 2000 Reward 2000.0 Steps 3198855
# Epoch 2000 Reward 2000.0 Steps 3200855
# Epoch 2000 Reward 2000.0 Steps 3202855
# Epoch 2000 Reward 2000.0 Steps 3204855
# Epoch 2000 Reward 2000.0 Steps 3206855
# Epoch 2000 Reward 2000.0 Steps 3208855
# Epoch 2000 Reward 2000.0 Steps 3210855
# Epoch 2000 Reward 2000.0 Steps 3212855
# Epoch 2000 Reward 2000.0 Steps 3214855
# Epoch 2000 Reward 2000.0 Steps 3216855
# Epoch 2000 Reward 2000.0 Steps 3218855
# Epoch 2000 Reward 2000.0 Steps 3220855
# Epoch 2000 Reward 2000.0 Steps 3222855
# Epoch 2000 Reward 2000.0 Steps 3224855
# Epoch 2000 Reward 2000.0 Steps 3226855
# Epoch 1901 Reward 1901.0 Steps 3228756
# Epoch 2000 Reward 2000.0 Steps 3230756
# Epoch 2000 Reward 2000.0 Steps 3232756
# Epoch 2000 Reward 2000.0 Steps 3234756
# Epoch 2000 Reward 2000.0 Steps 3236756
# Epoch 2000 Reward 2000.0 Steps 3238756
# Epoch 2000 Reward 2000.0 Steps 3240756
# Epoch 2000 Reward 2000.0 Steps 3242756
# Epoch 2000 Reward 2000.0 Steps 3244756
# Epoch 2000 Reward 2000.0 Steps 3246756
# Epoch 2000 Reward 2000.0 Steps 3248756
# Epoch 2000 Reward 2000.0 Steps 3250756
# Epoch 2000 Reward 2000.0 Steps 3252756
# Epoch 2000 Reward 2000.0 Steps 3254756
# Epoch 2000 Reward 2000.0 Steps 3256756
# Epoch 2000 Reward 2000.0 Steps 3258756
# Epoch 2000 Reward 2000.0 Steps 3260756
# Epoch 2000 Reward 2000.0 Steps 3262756
# Epoch 2000 Reward 2000.0 Steps 3264756
# Epoch 2000 Reward 2000.0 Steps 3266756
# Epoch 2000 Reward 2000.0 Steps 3268756
# Epoch 2000 Reward 2000.0 Steps 3270756
# Epoch 2000 Reward 2000.0 Steps 3272756
# Epoch 56 Reward 56.0 Steps 3272812
# Epoch 2000 Reward 2000.0 Steps 3388088
# Epoch 2000 Reward 2000.0 Steps 3390088
# Epoch 2000 Reward 2000.0 Steps 3392088
# Epoch 2000 Reward 2000.0 Steps 3394088
# Epoch 2000 Reward 2000.0 Steps 3396088
# Epoch 2000 Reward 2000.0 Steps 3398088
# Epoch 2000 Reward 2000.0 Steps 3400088
# Epoch 2000 Reward 2000.0 Steps 3402088
# Epoch 2000 Reward 2000.0 Steps 3404088
# Epoch 2000 Reward 2000.0 Steps 3406088
# Epoch 2000 Reward 2000.0 Steps 3408088
# Epoch 2000 Reward 2000.0 Steps 3410088
# Epoch 13 Reward 13.0 Steps 3410101
# Epoch 2000 Reward 2000.0 Steps 3412101
# Epoch 2000 Reward 2000.0 Steps 3414101
# Epoch 2000 Reward 2000.0 Steps 3416101
# Epoch 2000 Reward 2000.0 Steps 3418101
# Epoch 2000 Reward 2000.0 Steps 3420101
# Epoch 2000 Reward 2000.0 Steps 3422101
# Epoch 2000 Reward 2000.0 Steps 3424101
# Epoch 2000 Reward 2000.0 Steps 3426101
# Epoch 2000 Reward 2000.0 Steps 3428101
# Epoch 2000 Reward 2000.0 Steps 3430101
# Epoch 2000 Reward 2000.0 Steps 3432101
# Epoch 2000 Reward 2000.0 Steps 3434101
# Epoch 2000 Reward 2000.0 Steps 3436101
# Epoch 2000 Reward 2000.0 Steps 3438101
# Epoch 112 Reward 112.0 Steps 3438213
# Epoch 11 Reward 11.0 Steps 3438224
# Epoch 202 Reward 202.0 Steps 3438426
# Epoch 12 Reward 12.0 Steps 3438438
# Epoch 159 Reward 159.0 Steps 3438597
# Epoch 13 Reward 13.0 Steps 3438610
# Epoch 12 Reward 12.0 Steps 3438622
# Epoch 16 Reward 16.0 Steps 3438638
# Epoch 12 Reward 12.0 Steps 3438650
# Epoch 12 Reward 12.0 Steps 3438662
# Epoch 2000 Reward 2000.0 Steps 3440662
# Epoch 2000 Reward 2000.0 Steps 3442662
# Epoch 2000 Reward 2000.0 Steps 3444662
# Epoch 2000 Reward 2000.0 Steps 3446662
# Epoch 2000 Reward 2000.0 Steps 3448662
# Epoch 2000 Reward 2000.0 Steps 3450662
# Epoch 2000 Reward 2000.0 Steps 3452662
# Epoch 2000 Reward 2000.0 Steps 3454662
# Epoch 2000 Reward 2000.0 Steps 3456662
# Epoch 2000 Reward 2000.0 Steps 3458662
# Epoch 2000 Reward 2000.0 Steps 3460662
# Epoch 2000 Reward 2000.0 Steps 3462662
# Epoch 2000 Reward 2000.0 Steps 3464662
# Epoch 2000 Reward 2000.0 Steps 3466662
# Epoch 2000 Reward 2000.0 Steps 3468662
# Epoch 2000 Reward 2000.0 Steps 3470662
# Epoch 2000 Reward 2000.0 Steps 3472662
# Epoch 2000 Reward 2000.0 Steps 3474662
# Epoch 2000 Reward 2000.0 Steps 3476662
# Epoch 2000 Reward 2000.0 Steps 3478662
# Epoch 1622 Reward 1622.0 Steps 3480284
# Epoch 785 Reward 785.0 Steps 3481069
# Epoch 218 Reward 218.0 Steps 3481287
# Epoch 394 Reward 394.0 Steps 3481681
# Epoch 362 Reward 362.0 Steps 3482043
# Epoch 174 Reward 174.0 Steps 3482217
# Epoch 175 Reward 175.0 Steps 3482392
# Epoch 118 Reward 118.0 Steps 3482510
# Epoch 153 Reward 153.0 Steps 3482663
# Epoch 144 Reward 144.0 Steps 3482807
# Epoch 95 Reward 95.0 Steps 3482902
# Epoch 127 Reward 127.0 Steps 3483029
# Epoch 112 Reward 112.0 Steps 3483141
# Epoch 13 Reward 13.0 Steps 3483154
# Epoch 118 Reward 118.0 Steps 3483272
# Epoch 114 Reward 114.0 Steps 3483386
# Epoch 15 Reward 15.0 Steps 3483401
# Epoch 20 Reward 20.0 Steps 3483421
# Epoch 17 Reward 17.0 Steps 3483438
# Epoch 16 Reward 16.0 Steps 3483454
# Epoch 13 Reward 13.0 Steps 3483467
# Epoch 14 Reward 14.0 Steps 3483481
# Epoch 15 Reward 15.0 Steps 3483496
# Epoch 19 Reward 19.0 Steps 3483515
# Epoch 93 Reward 93.0 Steps 3483608
# Epoch 11 Reward 11.0 Steps 3483619
# Epoch 12 Reward 12.0 Steps 3483631
# Epoch 16 Reward 16.0 Steps 3483647
# Epoch 12 Reward 12.0 Steps 3483659
# Epoch 110 Reward 110.0 Steps 3483769
# Epoch 16 Reward 16.0 Steps 3483785
# Epoch 99 Reward 99.0 Steps 3483884
# Epoch 13 Reward 13.0 Steps 3483897
# Epoch 117 Reward 117.0 Steps 3484014
# Epoch 120 Reward 120.0 Steps 3484134
# Epoch 130 Reward 130.0 Steps 3484264
# Epoch 155 Reward 155.0 Steps 3484419
# Epoch 163 Reward 163.0 Steps 3484582
# Epoch 188 Reward 188.0 Steps 3484770
# Epoch 398 Reward 398.0 Steps 3485168
# Epoch 404 Reward 404.0 Steps 3485572
# Epoch 2000 Reward 2000.0 Steps 3487572
# Epoch 1436 Reward 1436.0 Steps 3489008
# Epoch 615 Reward 615.0 Steps 3489623
# Epoch 1293 Reward 1293.0 Steps 3490916
# Epoch 2000 Reward 2000.0 Steps 3492916
# Epoch 1045 Reward 1045.0 Steps 3493961
# Epoch 2000 Reward 2000.0 Steps 3495961
# Epoch 2000 Reward 2000.0 Steps 3497961
# Epoch 2000 Reward 2000.0 Steps 3499961
# Epoch 2000 Reward 2000.0 Steps 3501961
# Epoch 2000 Reward 2000.0 Steps 3503961
# Epoch 2000 Reward 2000.0 Steps 3505961
# Epoch 2000 Reward 2000.0 Steps 3507961
# Epoch 2000 Reward 2000.0 Steps 3509961
# Epoch 2000 Reward 2000.0 Steps 3511961
# Epoch 2000 Reward 2000.0 Steps 3513961
# Epoch 2000 Reward 2000.0 Steps 3515961
# Epoch 2000 Reward 2000.0 Steps 3517961
# Epoch 2000 Reward 2000.0 Steps 3519961
# Epoch 2000 Reward 2000.0 Steps 3521961
# Epoch 2000 Reward 2000.0 Steps 3523961
# Epoch 2000 Reward 2000.0 Steps 3525961
# Epoch 2000 Reward 2000.0 Steps 3527961
# Epoch 2000 Reward 2000.0 Steps 3529961
# Epoch 2000 Reward 2000.0 Steps 3531961
# Epoch 2000 Reward 2000.0 Steps 3533961
# Epoch 2000 Reward 2000.0 Steps 3535961
# Epoch 2000 Reward 2000.0 Steps 3537961
# Epoch 2000 Reward 2000.0 Steps 3539961
# Epoch 2000 Reward 2000.0 Steps 3541961
# Epoch 1778 Reward 1778.0 Steps 3543739
# Epoch 1295 Reward 1295.0 Steps 3545034
# Epoch 990 Reward 990.0 Steps 3546024
# Epoch 1439 Reward 1439.0 Steps 3547463
# Epoch 1375 Reward 1375.0 Steps 3548838
# Epoch 2000 Reward 2000.0 Steps 3550838
# Epoch 2000 Reward 2000.0 Steps 3552838
# Epoch 2000 Reward 2000.0 Steps 3554838
# Epoch 2000 Reward 2000.0 Steps 3556838
# Epoch 2000 Reward 2000.0 Steps 3558838
# Epoch 2000 Reward 2000.0 Steps 3560838
# Epoch 2000 Reward 2000.0 Steps 3562838
# Epoch 2000 Reward 2000.0 Steps 3564838
# Epoch 2000 Reward 2000.0 Steps 3566838
# Epoch 2000 Reward 2000.0 Steps 3568838
# Epoch 2000 Reward 2000.0 Steps 3570838
# Epoch 2000 Reward 2000.0 Steps 3572838
# Epoch 2000 Reward 2000.0 Steps 3574838
# Epoch 2000 Reward 2000.0 Steps 3576838
# Epoch 2000 Reward 2000.0 Steps 3578838
# Epoch 2000 Reward 2000.0 Steps 3580838
# Epoch 2000 Reward 2000.0 Steps 3582838
# Epoch 2000 Reward 2000.0 Steps 3584838
# Epoch 615 Reward 615.0 Steps 3585453
# Epoch 1095 Reward 1095.0 Steps 3586548
# Epoch 2000 Reward 2000.0 Steps 3588548
# Epoch 2000 Reward 2000.0 Steps 3590548
# Epoch 2000 Reward 2000.0 Steps 3592548
# Epoch 2000 Reward 2000.0 Steps 3594548
# Epoch 2000 Reward 2000.0 Steps 3596548
# Epoch 2000 Reward 2000.0 Steps 3598548
# Epoch 2000 Reward 2000.0 Steps 3600548
# Epoch 2000 Reward 2000.0 Steps 3602548
# Epoch 2000 Reward 2000.0 Steps 3604548
# Epoch 2000 Reward 2000.0 Steps 3606548
# Epoch 2000 Reward 2000.0 Steps 3608548
# Epoch 2000 Reward 2000.0 Steps 3610548
# Epoch 2000 Reward 2000.0 Steps 3612548
# Epoch 2000 Reward 2000.0 Steps 3614548
# Epoch 2000 Reward 2000.0 Steps 3616548
# Epoch 2000 Reward 2000.0 Steps 3618548
# Epoch 2000 Reward 2000.0 Steps 3620548
# Epoch 2000 Reward 2000.0 Steps 3622548
# Epoch 2000 Reward 2000.0 Steps 3624548
# Epoch 2000 Reward 2000.0 Steps 3626548
# Epoch 2000 Reward 2000.0 Steps 3628548
# Epoch 2000 Reward 2000.0 Steps 3630548
# Epoch 2000 Reward 2000.0 Steps 3632548
# Epoch 2000 Reward 2000.0 Steps 3634548
# Epoch 2000 Reward 2000.0 Steps 3636548
# Epoch 2000 Reward 2000.0 Steps 3638548
# Epoch 2000 Reward 2000.0 Steps 3640548
# Epoch 2000 Reward 2000.0 Steps 3642548
# Epoch 2000 Reward 2000.0 Steps 3644548
# Epoch 2000 Reward 2000.0 Steps 3646548
# Epoch 2000 Reward 2000.0 Steps 3648548
# Epoch 2000 Reward 2000.0 Steps 3650548
# Epoch 2000 Reward 2000.0 Steps 3652548
# Epoch 2000 Reward 2000.0 Steps 3654548
# Epoch 2000 Reward 2000.0 Steps 3656548
# Epoch 2000 Reward 2000.0 Steps 3658548
# Epoch 2000 Reward 2000.0 Steps 3660548
# Epoch 2000 Reward 2000.0 Steps 3662548
# Epoch 2000 Reward 2000.0 Steps 3664548
# Epoch 1567 Reward 1567.0 Steps 3666115
# Epoch 199 Reward 199.0 Steps 3666314
# Epoch 720 Reward 720.0 Steps 3667034
# Epoch 35 Reward 35.0 Steps 3667069
# Epoch 52 Reward 52.0 Steps 3667121
# Epoch 227 Reward 227.0 Steps 3667348
# Epoch 565 Reward 565.0 Steps 3667913
# Epoch 69 Reward 69.0 Steps 3667982
# Epoch 2000 Reward 2000.0 Steps 3669982
# Epoch 2000 Reward 2000.0 Steps 3671982
# Epoch 2000 Reward 2000.0 Steps 3673982
# Epoch 2000 Reward 2000.0 Steps 3675982
# Epoch 2000 Reward 2000.0 Steps 3677982
# Epoch 2000 Reward 2000.0 Steps 3679982
# Epoch 2000 Reward 2000.0 Steps 3681982
# Epoch 2000 Reward 2000.0 Steps 3683982
# Epoch 2000 Reward 2000.0 Steps 3685982
# Epoch 2000 Reward 2000.0 Steps 3687982
# Epoch 2000 Reward 2000.0 Steps 3689982
# Epoch 2000 Reward 2000.0 Steps 3691982
# Epoch 2000 Reward 2000.0 Steps 3693982
# Epoch 2000 Reward 2000.0 Steps 3695982
# Epoch 2000 Reward 2000.0 Steps 3697982
# Epoch 2000 Reward 2000.0 Steps 3699982
# Epoch 2000 Reward 2000.0 Steps 3701982
# Epoch 2000 Reward 2000.0 Steps 3703982
# Epoch 2000 Reward 2000.0 Steps 3705982
# Epoch 2000 Reward 2000.0 Steps 3707982
# Epoch 2000 Reward 2000.0 Steps 3709982
# Epoch 2000 Reward 2000.0 Steps 3711982
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-737be0e9bcd9> in <module>()
#      43
#      44                 # sample experience
# ---> 45                 o_obs, o_act, o_next_obs, o_rew, o_done = sample_memories(batch_size)
#      46
#      47                 # states
#
# <ipython-input-8-4fc35f545fef> in sample_memories(batch_size)
#       1 def sample_memories(batch_size):
#       2     perm_batch = np.random.permutation(len(exp_buffer))[:batch_size]
# ----> 3     mem = np.array(exp_buffer)[perm_batch]
#       4     return mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]
#
# KeyboardInterrupt:

# %%
N = 10
cumsum, moving_aves = [0], []

for i, x in enumerate(rewards_of_episode, 1):
    cumsum.append(cumsum[i-1] + x)
    if i>=N:
        moving_ave = (cumsum[i] - cumsum[i-N])/N
        #can do stuff with moving_ave here
        moving_aves.append(moving_ave)

# %%
plt.plot(list(range(len(moving_aves))), moving_aves)

# %%
epsilon

# %%
plt.plot(list(range(len(number_of_epochs))), rewards_of_episode)
